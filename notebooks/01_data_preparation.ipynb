# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

# %%
from data_loader import load_alagoas_data, load_tte_data
from data_processor import clean_and_process_alagoas_data, clean_and_process_tte_data
import pandas as pd

# %% [markdown]
# # Data Preparation Notebook
#
# This notebook loads the raw data, performs initial cleaning and processing, and saves the processed data for further analysis in other notebooks.

# %%
# Load Alagoas Data
alagoas_raw_path = '../data/raw/perfil_comparecimento_abstencao_2024_AL.csv'
df_alagoas_raw = load_alagoas_data(alagoas_raw_path)
df_alagoas_processed = clean_and_process_alagoas_data(df_alagoas_raw)

# Save Processed Alagoas Data (optional, but good practice for large datasets)

# %%
# Load TTE Data
tte_raw_path = '../data/raw/comparecimento_abstencao_eleitor_tte_2024.csv'
df_tte_raw = load_tte_data(tte_raw_path)
df_tte_processed = clean_and_process_tte_data(df_tte_raw)

# Save Processed TTE Data (optional)

# %%
# Display head of processed dataframes to verify
print("Alagoas Processed Data Head:")
print(df_alagoas_processed.head())
print("TTE Processed Data Head:")
print(df_tte_processed.head())
# Out:
# Alagoas Processed Data Head:
#    DT_GERACAO HH_GERACAO ANO_ELEICAO NR_TURNO SG_UF CD_MUNICIPIO NM_MUNICIPIO  \
# 0  06/11/2024   10:09:27        2024        1    AL        27006   PARIPUEIRA
# 1  06/11/2024   10:09:27        2024        1    AL        27006   PARIPUEIRA
# 2  06/11/2024   10:09:27        2024        1    AL        27006   PARIPUEIRA
# 3  06/11/2024   10:09:27        2024        1    AL        27006   PARIPUEIRA
# 4  06/11/2024   10:09:27        2024        1    AL        27006   PARIPUEIRA
#
#   NR_ZONA CD_GENERO  DS_GENERO  ... DS_GRUPO_INDIGENA QT_APTOS  \
# 0      17         2  MASCULINO  ...     NÃO INFORMADO        1
# 1      17         2  MASCULINO  ...     NÃO INFORMADO       39
# 2      17         2  MASCULINO  ...     NÃO INFORMADO        1
# 3      17         2  MASCULINO  ...     NÃO INFORMADO        3
# 4      17         2  MASCULINO  ...     NÃO INFORMADO       16
#
#   QT_COMPARECIMENTO QT_ABSTENCAO QT_COMPARECIMENTO_DEFICIENCIA  \
# ...
