# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

# %%
from data_loader import load_tte_data
from data_processor import clean_and_process_tte_data
from visualizer import (
    plot_tte_comparecimento_abstencao_uf,
    plot_tte_comparecimento_abstencao_faixa_etaria,
    plot_tte_comparecimento_tipo_transferencia
)

# %% [markdown]
# # TTE Analysis Notebook
#
# This notebook performs analysis and generates visualizations for the Temporary Transfer of Electoral Title (TTE) data.

# %%
# Load and Process Data
tte_raw_path = '../data/raw/comparecimento_abstencao_eleitor_tte_2024.csv'
df_tte = load_tte_data(tte_raw_path)
df_tte = clean_and_process_tte_data(df_tte)

# %% [markdown]
# ## Visualizations

# %%
plot_tte_comparecimento_abstencao_uf(df_tte)

# %%
plot_tte_comparecimento_abstencao_faixa_etaria(df_tte)
# Out:
# c:\Users\evert\OneDrive\Área de Trabalho\elei-oes\src\visualizer.py:201: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=45)

# %%
plot_tte_comparecimento_tipo_transferencia(df_tte)
