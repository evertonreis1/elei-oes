# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

# %%
from data_loader import load_alagoas_data
from data_processor import clean_and_process_alagoas_data, calculate_disability_percentages
from visualizer import (
    plot_turnout_abstention_by_gender,
    plot_turnout_abstention_by_age_group,
    plot_turnout_abstention_by_educational_level,
    plot_comparecimento_faixa_etaria_pct,
    plot_abstencao_grau_escolaridade_pct,
    plot_comparecimento_genero_pct,
    plot_distribuicao_comparecimento_pct,
    plot_comparecimento_vs_abstencao_faixa_etaria,
    plot_comparecimento_vs_abstencao_grau_escolaridade,
    plot_comparecimento_vs_abstencao_cidade,
    plot_comparecimento_vs_abstencao_deficiencia,
    plot_faixa_etaria_maior_comparecimento,
    plot_distribuicao_percentual_comparecimento_faixa_etaria
)

# %% [markdown]
# # Alagoas Analysis Notebook
#
# This notebook performs analysis and generates visualizations for the Alagoas voter profile data.

# %%
# Load and Process Data
alagoas_raw_path = '../data/raw/perfil_comparecimento_abstencao_2024_AL.csv'
df_alagoas = load_alagoas_data(alagoas_raw_path)
df_alagoas = clean_and_process_alagoas_data(df_alagoas)
df_alagoas = calculate_disability_percentages(df_alagoas) # Apply disability processing if needed for plots

# %% [markdown]
# ## Visualizations

# %%
plot_turnout_abstention_by_gender(df_alagoas)

# %%
plot_turnout_abstention_by_age_group(df_alagoas)

# %%
plot_turnout_abstention_by_educational_level(df_alagoas)

# %%
plot_comparecimento_faixa_etaria_pct(df_alagoas)

# %%
plot_abstencao_grau_escolaridade_pct(df_alagoas)

# %%
plot_comparecimento_genero_pct(df_alagoas)

# %%
plot_distribuicao_comparecimento_pct(df_alagoas)

# %%
plot_comparecimento_vs_abstencao_faixa_etaria(df_alagoas)

# %%
plot_comparecimento_vs_abstencao_grau_escolaridade(df_alagoas)

# %%
plot_comparecimento_vs_abstencao_cidade(df_alagoas)

# %%
plot_comparecimento_vs_abstencao_deficiencia(df_alagoas)

# %%
plot_faixa_etaria_maior_comparecimento(df_alagoas)

# %%
plot_distribuicao_percentual_comparecimento_faixa_etaria(df_alagoas)
